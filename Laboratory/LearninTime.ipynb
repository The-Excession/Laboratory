# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
sns.lineplot(x=[0, 1, 2], y=[0, 1, 4])
# Out:
# <Axes: >

# %%
#Assert allows debugging by testing conditions that must be true. If condition is not true, fails

x = 5
y = 6
assert x == 5 # Passes. Cannot put assert into an if statement as a condition. Only x==5 
assert y > 10, "x is not greater than 10"  # Fails with AssertionError
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 6
#       4 y = 6
#       5 assert x == 5 # Passes. Cannot put assert into an if statement as a condition. Only x==5
# ----> 6 assert y > 10, "x is not greater than 10"  # Fails with AssertionError
#
# AssertionError: x is not greater than 10
